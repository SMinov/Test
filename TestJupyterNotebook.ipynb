# %% [markdown]
# ## What is going on
#
# ![wbOdizzy_surreal_planets_galaxy_mystic_4k_hyperrealistic_block__31d82587-91c5-40d0-8016-5e98614ba544.png](attachment:e749335b-413b-48a1-b033-61cc57c57d7a.png)

# %%
a = 13
b = 13
sum = a + b
print(sum)
# Out:
# 26

# %%
print("I AM TEXT")
# Out:
# I AM TEXT

# %% [raw]
# raw text here
